# %%
import pandas as pd
import numpy as np

df=pd.read_csv('NY RENTS BY YEAR.csv', index_col=0,na_values=['#DIV/0!'])
df=df.dropna(how='all')
df
# Out:
#                        Borough         2011         2012         2013  \
# areaName
# All Downtown         Manhattan  3446.000000  3548.750000  3557.916667
# All Midtown          Manhattan  3284.000000  3364.583333  3389.583333
# All Upper East Side  Manhattan  2648.750000  2752.500000  2794.583333
# All Upper Manhattan  Manhattan  1932.583333  2000.250000  2041.666667
# All Upper West Side  Manhattan  3151.500000  3247.833333  3226.250000
# ...                        ...          ...          ...          ...
# Windsor Terrace       Brooklyn  2184.416667  2182.333333  2345.416667
# Woodhaven               Queens          NaN          NaN          NaN
# Woodlawn                 Bronx          NaN          NaN          NaN
# Woodside                Queens  1380.500000          NaN  1633.333333
# Woodstock                Bronx          NaN          NaN          NaN
#
#                             2014         2015         2016         2017  \
# areaName
# ...

# %%
df_borough=df.groupby('Borough')['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'].mean().round(2)
df_borough

#df.groupby("Borough").mean()
# Out:
# /var/folders/fh/9zkgzlyn1pbb3rzjsj7x28j00000gn/T/ipykernel_44840/623451040.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_borough=df.groupby('Borough')['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'].mean().round(2)
#                   2011     2012     2013     2014     2015     2016     2017  \
# Borough
# Bronx          1278.47  1522.17  1394.64  1373.63  1488.07  1609.03  1710.52
# Brooklyn       2048.54  2131.77  2214.55  2273.74  2358.36  2450.28  2409.75
# Manhattan      3195.90  3279.16  3311.67  3337.52  3454.23  3582.22  3464.87
# Queens         1616.86  1862.97  1824.37  1841.41  1902.98  1991.14  2071.03
# Staten Island      NaN  1562.86  1614.67  1652.17  1690.08  1988.75  1927.58
#
#                   2018     2019     2020
# Borough
# Bronx          1807.15  1856.47  1881.45
# Brooklyn       2460.76  2559.61  2504.67
# ...

# %%
df_borough.to_csv('Average Rent By Borough.csv', index=True)
